# %%
# Open the file in read mode
with open('sample.txt', 'r') as file:
    # Read the contents of the file into a string
    text = file.read()

# Print the contents of the string
print(text)
# Out:
# Text analytics, also known as text mining, is the process of deriving meaningful insights and patterns from unstructured text data. With the rise of the internet and social media, the amount of text data generated daily has skyrocketed, making text analytics an essential tool for businesses and organizations seeking to extract insights from this data.In this essay, we will explore the different techniques used in text analytics, the benefits of text analytics, and the challenges that come with implementing text analytics.Text analytics can be broadly divided into three main techniques: text classification, sentiment analysis, and topic modeling.Text classification involves categorizing text data into predefined categories. This can be useful for automating tasks such as spam detection, content filtering, and customer feedback analysis. For example, a company might use text classification to automatically route customer complaints to the appropriate department.Sentiment analysis, also known as opinion mining, involves determining the sentiment of a piece of text data, whether it is positive, negative, or neutral. This technique is useful for analyzing customer feedback, social media posts, and news articles. For example, a company might use sentiment analysis to track customer sentiment towards a new product launch.Topic modeling involves identifying the topics discussed in a piece of text data. This technique is useful for identifying themes in customer feedback, social media posts, and news articles. For example, a company might use topic modeling to identify the most commonly discussed topics in customer reviews of their products.The benefits of text analytics are numerous. By analyzing large amounts of text data, businesses and organizations can gain valuable insights into customer behavior, market trends, and brand reputation. For example, a company might use text analytics to identify common complaints among their customers and take steps to address them. Similarly, a marketing team might use text analytics to identify popular keywords and phrases in social media posts to inform their advertising strategy.Despite its many benefits, implementing text analytics can be challenging. One of the main challenges is dealing with the vast amounts of data generated by social media and other online platforms. In order to make sense of this data, businesses and organizations must invest in powerful computing resources and sophisticated algorithms.Another challenge is ensuring the accuracy of the analysis. Since text data is often ambiguous and prone to errors, it is important to have a robust quality assurance process in place to ensure that the insights derived from text analytics are reliable.In addition to these challenges, there are also ethical considerations that must be taken into account when implementing text analytics. For example, businesses and organizations must be mindful of privacy concerns when collecting and analyzing customer data.Despite these challenges, text analytics is becoming an increasingly important tool for businesses and organizations seeking to stay competitive in today's data-driven economy. By leveraging the insights derived from text analytics, businesses can make informed decisions, improve customer satisfaction, and gain a competitive edge in their market. As such, it is likely that we will see continued growth in the use of text analytics in the years to come.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# TOKENIZATION 
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(text)


#STOP WORDS REMOVAL
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
filtered_sentence = []
for w in word_tokens:
	if w not in stop_words:
		filtered_sentence.append(w)

print(word_tokens)
# Out:
# ['Text', 'analytics', ',', 'also', 'known', 'as', 'text', 'mining', ',', 'is', 'the', 'process', 'of', 'deriving', 'meaningful', 'insights', 'and', 'patterns', 'from', 'unstructured', 'text', 'data', '.', 'With', 'the', 'rise', 'of', 'the', 'internet', 'and', 'social', 'media', ',', 'the', 'amount', 'of', 'text', 'data', 'generated', 'daily', 'has', 'skyrocketed', ',', 'making', 'text', 'analytics', 'an', 'essential', 'tool', 'for', 'businesses', 'and', 'organizations', 'seeking', 'to', 'extract', 'insights', 'from', 'this', 'data.In', 'this', 'essay', ',', 'we', 'will', 'explore', 'the', 'different', 'techniques', 'used', 'in', 'text', 'analytics', ',', 'the', 'benefits', 'of', 'text', 'analytics', ',', 'and', 'the', 'challenges', 'that', 'come', 'with', 'implementing', 'text', 'analytics.Text', 'analytics', 'can', 'be', 'broadly', 'divided', 'into', 'three', 'main', 'techniques', ':', 'text', 'classification', ',', 'sentiment', 'analysis', ',', 'and', 'topic', 'modeling.Text', 'classification', 'involves', 'categorizing', 'text', 'data', 'into', 'predefined', 'categories', '.', 'This', 'can', 'be', 'useful', 'for', 'automating', 'tasks', 'such', 'as', 'spam', 'detection', ',', 'content', 'filtering', ',', 'and', 'customer', 'feedback', 'analysis', '.', 'For', 'example', ',', 'a', 'company', 'might', 'use', 'text', 'classification', 'to', 'automatically', 'route', 'customer', 'complaints', 'to', 'the', 'appropriate', 'department.Sentiment', 'analysis', ',', 'also', 'known', 'as', 'opinion', 'mining', ',', 'involves', 'determining', 'the', 'sentiment', 'of', 'a', 'piece', 'of', 'text', 'data', ',', 'whether', 'it', 'is', 'positive', ',', 'negative', ',', 'or', 'neutral', '.', 'This', 'technique', 'is', 'useful', 'for', 'analyzing', 'customer', 'feedback', ',', 'social', 'media', 'posts', ',', 'and', 'news', 'articles', '.', 'For', 'example', ',', 'a', 'company', 'might', 'use', 'sentiment', 'analysis', 'to', 'track', 'customer', 'sentiment', 'towards', 'a', 'new', 'product', 'launch.Topic', 'modeling', 'involves', 'identifying', 'the', 'topics', 'discussed', 'in', 'a', 'piece', 'of', 'text', 'data', '.', 'This', 'technique', 'is', 'useful', 'for', 'identifying', 'themes', 'in', 'customer', 'feedback', ',', 'social', 'media', 'posts', ',', 'and', 'news', 'articles', '.', 'For', 'example', ',', 'a', 'company', 'might', 'use', 'topic', 'modeling', 'to', 'identify', 'the', 'most', 'commonly', 'discussed', 'topics', 'in', 'customer', 'reviews', 'of', 'their', 'products.The', 'benefits', 'of', 'text', 'analytics', 'are', 'numerous', '.', 'By', 'analyzing', 'large', 'amounts', 'of', 'text', 'data', ',', 'businesses', 'and', 'organizations', 'can', 'gain', 'valuable', 'insights', 'into', 'customer', 'behavior', ',', 'market', 'trends', ',', 'and', 'brand', 'reputation', '.', 'For', 'example', ',', 'a', 'company', 'might', 'use', 'text', 'analytics', 'to', 'identify', 'common', 'complaints', 'among', 'their', 'customers', 'and', 'take', 'steps', 'to', 'address', 'them', '.', 'Similarly', ',', 'a', 'marketing', 'team', 'might', 'use', 'text', 'analytics', 'to', 'identify', 'popular', 'keywords', 'and', 'phrases', 'in', 'social', 'media', 'posts', 'to', 'inform', 'their', 'advertising', 'strategy.Despite', 'its', 'many', 'benefits', ',', 'implementing', 'text', 'analytics', 'can', 'be', 'challenging', '.', 'One', 'of', 'the', 'main', 'challenges', 'is', 'dealing', 'with', 'the', 'vast', 'amounts', 'of', 'data', 'generated', 'by', 'social', 'media', 'and', 'other', 'online', 'platforms', '.', 'In', 'order', 'to', 'make', 'sense', 'of', 'this', 'data', ',', 'businesses', 'and', 'organizations', 'must', 'invest', 'in', 'powerful', 'computing', 'resources', 'and', 'sophisticated', 'algorithms.Another', 'challenge', 'is', 'ensuring', 'the', 'accuracy', 'of', 'the', 'analysis', '.', 'Since', 'text', 'data', 'is', 'often', 'ambiguous', 'and', 'prone', 'to', 'errors', ',', 'it', 'is', 'important', 'to', 'have', 'a', 'robust', 'quality', 'assuran ...

# %%
# POS TAGGING
pos_tagged = nltk.pos_tag(word_tokens)
print(pos_tagged)
# Out:
# [('Text', 'NN'), ('analytics', 'NNS'), (',', ','), ('also', 'RB'), ('known', 'VBN'), ('as', 'IN'), ('text', 'NN'), ('mining', 'NN'), (',', ','), ('is', 'VBZ'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('deriving', 'VBG'), ('meaningful', 'JJ'), ('insights', 'NNS'), ('and', 'CC'), ('patterns', 'NNS'), ('from', 'IN'), ('unstructured', 'JJ'), ('text', 'NN'), ('data', 'NNS'), ('.', '.'), ('With', 'IN'), ('the', 'DT'), ('rise', 'NN'), ('of', 'IN'), ('the', 'DT'), ('internet', 'NN'), ('and', 'CC'), ('social', 'JJ'), ('media', 'NNS'), (',', ','), ('the', 'DT'), ('amount', 'NN'), ('of', 'IN'), ('text', 'NN'), ('data', 'NNS'), ('generated', 'VBD'), ('daily', 'RB'), ('has', 'VBZ'), ('skyrocketed', 'VBN'), (',', ','), ('making', 'VBG'), ('text', 'JJ'), ('analytics', 'NNS'), ('an', 'DT'), ('essential', 'JJ'), ('tool', 'NN'), ('for', 'IN'), ('businesses', 'NNS'), ('and', 'CC'), ('organizations', 'NNS'), ('seeking', 'VBG'), ('to', 'TO'), ('extract', 'VB'), ('insights', 'NNS'), ('from', 'IN'), ('this', 'DT'), ('data.In', 'NN'), ('this', 'DT'), ('essay', 'NN'), (',', ','), ('we', 'PRP'), ('will', 'MD'), ('explore', 'VB'), ('the', 'DT'), ('different', 'JJ'), ('techniques', 'NNS'), ('used', 'VBN'), ('in', 'IN'), ('text', 'JJ'), ('analytics', 'NNS'), (',', ','), ('the', 'DT'), ('benefits', 'NNS'), ('of', 'IN'), ('text', 'NN'), ('analytics', 'NNS'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('challenges', 'NNS'), ('that', 'IN'), ('come', 'VBP'), ('with', 'IN'), ('implementing', 'VBG'), ('text', 'JJ'), ('analytics.Text', 'JJ'), ('analytics', 'NNS'), ('can', 'MD'), ('be', 'VB'), ('broadly', 'RB'), ('divided', 'VBN'), ('into', 'IN'), ('three', 'CD'), ('main', 'JJ'), ('techniques', 'NNS'), (':', ':'), ('text', 'NN'), ('classification', 'NN'), (',', ','), ('sentiment', 'NN'), ('analysis', 'NN'), (',', ','), ('and', 'CC'), ('topic', 'NN'), ('modeling.Text', 'JJ'), ('classification', 'NN'), ('involves', 'VBZ'), ('categorizing', 'VBG'), ('text', 'NN'), ('data', 'NNS'), ('into', 'IN'), ('predefined', 'JJ'), ('categories', 'NNS'), ('.', '.'), ('This', 'DT'), ('can', 'MD'), ('be', 'VB'), ('useful', 'JJ'), ('for', 'IN'), ('automating', 'VBG'), ('tasks', 'NNS'), ('such', 'JJ'), ('as', 'IN'), ('spam', 'JJ'), ('detection', 'NN'), (',', ','), ('content', 'NN'), ('filtering', 'NN'), (',', ','), ('and', 'CC'), ('customer', 'NN'), ('feedback', 'NN'), ('analysis', 'NN'), ('.', '.'), ('For', 'IN'), ('example', 'NN'), (',', ','), ('a', 'DT'), ('company', 'NN'), ('might', 'MD'), ('use', 'VB'), ('text', 'JJ'), ('classification', 'NN'), ('to', 'TO'), ('automatically', 'RB'), ('route', 'VB'), ('customer', 'NN'), ('complaints', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('appropriate', 'JJ'), ('department.Sentiment', 'NN'), ('analysis', 'NN'), (',', ','), ('also', 'RB'), ('known', 'VBN'), ('as', 'IN'), ('opinion', 'NN'), ('mining', 'NN'), (',', ','), ('involves', 'VBZ'), ('determining', 'VBG'), ('the', 'DT'), ('sentiment', 'NN'), ('of', 'IN'), ('a', 'DT'), ('piece', 'NN'), ('of', 'IN'), ('text', 'NN'), ('data', 'NNS'), (',', ','), ('whether', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('positive', 'JJ'), (',', ','), ('negative', 'JJ'), (',', ','), ('or', 'CC'), ('neutral', 'JJ'), ('.', '.'), ('This', 'DT'), ('technique', 'NN'), ('is', 'VBZ'), ('useful', 'JJ'), ('for', 'IN'), ('analyzing', 'VBG'), ('customer', 'NN'), ('feedback', 'NN'), (',', ','), ('social', 'JJ'), ('media', 'NNS'), ('posts', 'NNS'), (',', ','), ('and', 'CC'), ('news', 'NN'), ('articles', 'NNS'), ('.', '.'), ('For', 'IN'), ('example', 'NN'), (',', ','), ('a', 'DT'), ('company', 'NN'), ('might', 'MD'), ('use', 'VB'), ('sentiment', 'JJ'), ('analysis', 'NN'), ('to', 'TO'), ('track', 'VB'), ('customer', 'NN'), ('sentiment', 'NN'), ('towards', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('product', 'NN'), ('launch.Topic', 'NN'), ('modeling', 'VBG'), ('involves', 'NNS'), ('identifying', 'VBG'), ('the', 'DT'), ('topics', 'NNS'), ('discussed', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('piece', 'NN'), ('of', 'IN'), ('text', 'JJ'), ('da ...

# %%
print(filtered_sentence)
# Out:
# ['Text', 'analytics', ',', 'also', 'known', 'text', 'mining', ',', 'process', 'deriving', 'meaningful', 'insights', 'patterns', 'unstructured', 'text', 'data', '.', 'With', 'rise', 'internet', 'social', 'media', ',', 'amount', 'text', 'data', 'generated', 'daily', 'skyrocketed', ',', 'making', 'text', 'analytics', 'essential', 'tool', 'businesses', 'organizations', 'seeking', 'extract', 'insights', 'data.In', 'essay', ',', 'explore', 'different', 'techniques', 'used', 'text', 'analytics', ',', 'benefits', 'text', 'analytics', ',', 'challenges', 'come', 'implementing', 'text', 'analytics.Text', 'analytics', 'broadly', 'divided', 'three', 'main', 'techniques', ':', 'text', 'classification', ',', 'sentiment', 'analysis', ',', 'topic', 'modeling.Text', 'classification', 'involves', 'categorizing', 'text', 'data', 'predefined', 'categories', '.', 'This', 'useful', 'automating', 'tasks', 'spam', 'detection', ',', 'content', 'filtering', ',', 'customer', 'feedback', 'analysis', '.', 'For', 'example', ',', 'company', 'might', 'use', 'text', 'classification', 'automatically', 'route', 'customer', 'complaints', 'appropriate', 'department.Sentiment', 'analysis', ',', 'also', 'known', 'opinion', 'mining', ',', 'involves', 'determining', 'sentiment', 'piece', 'text', 'data', ',', 'whether', 'positive', ',', 'negative', ',', 'neutral', '.', 'This', 'technique', 'useful', 'analyzing', 'customer', 'feedback', ',', 'social', 'media', 'posts', ',', 'news', 'articles', '.', 'For', 'example', ',', 'company', 'might', 'use', 'sentiment', 'analysis', 'track', 'customer', 'sentiment', 'towards', 'new', 'product', 'launch.Topic', 'modeling', 'involves', 'identifying', 'topics', 'discussed', 'piece', 'text', 'data', '.', 'This', 'technique', 'useful', 'identifying', 'themes', 'customer', 'feedback', ',', 'social', 'media', 'posts', ',', 'news', 'articles', '.', 'For', 'example', ',', 'company', 'might', 'use', 'topic', 'modeling', 'identify', 'commonly', 'discussed', 'topics', 'customer', 'reviews', 'products.The', 'benefits', 'text', 'analytics', 'numerous', '.', 'By', 'analyzing', 'large', 'amounts', 'text', 'data', ',', 'businesses', 'organizations', 'gain', 'valuable', 'insights', 'customer', 'behavior', ',', 'market', 'trends', ',', 'brand', 'reputation', '.', 'For', 'example', ',', 'company', 'might', 'use', 'text', 'analytics', 'identify', 'common', 'complaints', 'among', 'customers', 'take', 'steps', 'address', '.', 'Similarly', ',', 'marketing', 'team', 'might', 'use', 'text', 'analytics', 'identify', 'popular', 'keywords', 'phrases', 'social', 'media', 'posts', 'inform', 'advertising', 'strategy.Despite', 'many', 'benefits', ',', 'implementing', 'text', 'analytics', 'challenging', '.', 'One', 'main', 'challenges', 'dealing', 'vast', 'amounts', 'data', 'generated', 'social', 'media', 'online', 'platforms', '.', 'In', 'order', 'make', 'sense', 'data', ',', 'businesses', 'organizations', 'must', 'invest', 'powerful', 'computing', 'resources', 'sophisticated', 'algorithms.Another', 'challenge', 'ensuring', 'accuracy', 'analysis', '.', 'Since', 'text', 'data', 'often', 'ambiguous', 'prone', 'errors', ',', 'important', 'robust', 'quality', 'assurance', 'process', 'place', 'ensure', 'insights', 'derived', 'text', 'analytics', 'reliable.In', 'addition', 'challenges', ',', 'also', 'ethical', 'considerations', 'must', 'taken', 'account', 'implementing', 'text', 'analytics', '.', 'For', 'example', ',', 'businesses', 'organizations', 'must', 'mindful', 'privacy', 'concerns', 'collecting', 'analyzing', 'customer', 'data.Despite', 'challenges', ',', 'text', 'analytics', 'becoming', 'increasingly', 'important', 'tool', 'businesses', 'organizations', 'seeking', 'stay', 'competitive', 'today', "'s", 'data-driven', 'economy', '.', 'By', 'leveraging', 'insights', 'derived', 'text', 'analytics', ',', 'businesses', 'make', 'informed', 'decisions', ',', 'improve', 'customer', 'satisfaction', ',', 'gain', 'competitive', 'edge', 'market', '.', 'As', ',', 'likely',  ...

# %%
#STEMMING
from nltk.stem import PorterStemmer
ps = PorterStemmer()

stemmed = []

for w in filtered_sentence:
    stemmed.append(ps.stem(w))
    print(w, " : ", ps.stem(w))
# Out:
# Text  :  text
# analytics  :  analyt
# ,  :  ,
# also  :  also
# known  :  known
# text  :  text
# mining  :  mine
# ,  :  ,
# process  :  process
# deriving  :  deriv
# meaningful  :  meaning
# insights  :  insight
# patterns  :  pattern
# unstructured  :  unstructur
# text  :  text
# data  :  data
# .  :  .
# With  :  with
# rise  :  rise
# internet  :  internet
# social  :  social
# media  :  media
# ,  :  ,
# amount  :  amount
# text  :  text
# data  :  data
# generated  :  gener
# daily  :  daili
# skyrocketed  :  skyrocket
# ,  :  ,
# making  :  make
# text  :  text
# analytics  :  analyt
# essential  :  essenti
# tool  :  tool
# businesses  :  busi
# organizations  :  organ
# seeking  :  seek
# extract  :  extract
# insights  :  insight
# data.In  :  data.in
# essay  :  essay
# ,  :  ,
# explore  :  explor
# different  :  differ
# techniques  :  techniqu
# used  :  use
# text  :  text
# analytics  :  analyt
# ,  :  ,
# benefits  :  benefit
# text  :  text
# analytics  :  analyt
# ,  :  ,
# challenges  :  challeng
# come  :  come
# implementing  :  implement
# text  :  text
# analytics.Text  :  analytics.text
# analytics  :  analyt
# broadly  :  broadli
# divided  :  divid
# three  :  three
# main  :  main
# techniques  :  techniqu
# :  :  :
# text  :  text
# classification  :  classif
# ,  :  ,
# sentiment  :  sentiment
# analysis  :  analysi
# ,  :  ,
# topic  :  topic
# modeling.Text  :  modeling.text
# classification  :  classif
# involves  :  involv
# categorizing  :  categor
# text  :  text
# data  :  data
# predefined  :  predefin
# categories  :  categori
# .  :  .
# This  :  thi
# useful  :  use
# automating  :  autom
# tasks  :  task
# spam  :  spam
# detection  :  detect
# ,  :  ,
# content  :  content
# filtering  :  filter
# ,  :  ,
# customer  :  custom
# feedback  :  feedback
# analysis  :  analysi
# .  :  .
# For  :  for
# example  :  exampl
# ,  :  ,
# company  :  compani
# might  :  might
# use  :  use
# text  :  text
# classification  :  classif
# automatically  :  automat
# route  :  rout
# customer  :  custom
# complaints  :  complaint
# appropriate  :  appropri
# department.Sentiment  :  department.senti
# analysis  :  analysi
# ,  :  ,
# also  :  also
# known  :  known
# opinion  :  opinion
# mining  :  mine
# ,  :  ,
# involves  :  involv
# determining  :  determin
# sentiment  :  sentiment
# piece  :  piec
# text  :  text
# data  :  data
# ,  :  ,
# whether  :  whether
# positive  :  posit
# ,  :  ,
# negative  :  neg
# ,  :  ,
# neutral  :  neutral
# .  :  .
# This  :  thi
# technique  :  techniqu
# useful  :  use
# analyzing  :  analyz
# customer  :  custom
# feedback  :  feedback
# ,  :  ,
# social  :  social
# media  :  media
# posts  :  post
# ,  :  ,
# news  :  news
# articles  :  articl
# .  :  .
# For  :  for
# example  :  exampl
# ,  :  ,
# company  :  compani
# might  :  might
# use  :  use
# sentiment  :  sentiment
# analysis  :  analysi
# track  :  track
# customer  :  custom
# sentiment  :  sentiment
# towards  :  toward
# new  :  new
# product  :  product
# launch.Topic  :  launch.top
# modeling  :  model
# involves  :  involv
# identifying  :  identifi
# topics  :  topic
# discussed  :  discuss
# piece  :  piec
# text  :  text
# data  :  data
# .  :  .
# This  :  thi
# technique  :  techniqu
# useful  :  use
# identifying  :  identifi
# themes  :  theme
# customer  :  custom
# feedback  :  feedback
# ,  :  ,
# social  :  social
# media  :  media
# posts  :  post
# ,  :  ,
# news  :  news
# articles  :  articl
# .  :  .
# For  :  for
# example  :  exampl
# ,  :  ,
# company  :  compani
# might  :  might
# use  :  use
# topic  :  topic
# modeling  :  model
# identify  :  identifi
# commonly  :  commonli
# discussed  :  discuss
# topics  :  topic
# customer  :  custom
# reviews  :  review
# products.The  :  products.th
# benefits  :  benefit
# text  :  text
# analytics  :  analyt
# numerous  :  numer
# .  :  .
# By  :  by
# analyzing  :  analyz
# large  :  larg
# amounts  :  amount
# text  :  text
# data  :  data
# ,  :  ,
# businesses  :  busi
# organizations  :  organ
# gain  :  gain
# valuable  :  valuabl
# insights  :  insight
# customer  :  custom
# behavior  :  behavior
# ,  :  ,
# market  :  market
# trends  :  trend
# ,  :  ,
# brand  :  brand
# reputation  :  reput
# .  :  .
# For  :  for
# example  :  exampl
# ,  :  ,
# company  :  compani
# might  :  might
# use  :  use
# text  :  text
# analytics  :  analyt
# identify  :  identifi
# common  :  common
# complaints  :  complaint
# among  :  among
# customers  :  custom
# take  :  take
# steps  :  step
# address  :  address
# .  :  .
# Similarly  :  similarli
# ,  :  ,
# marketing  :  market
# team  :  team
# might  :  might
# use  :  use
# text  :  text
# analytics  :  analyt
# identify  :  identifi
# popular  :  popular
# keywords  :  keyword
# phrases  :  phrase
# social  :  social
# media  :  media
# posts  :  post
# inform  :  inform
# advertising  :  advertis
# strategy.Despite  :  strategy.despit
# many  :  mani
# benefits  :  benefit
# ,  :  ,
# implementing  :  implement
# text  :  text
# analytics  :  analyt
# challenging  :  challeng
# .  :  .
# One  :  one
# main  :  main
# challenges  :  challeng
# dealing  :  deal
# vast  :  vast
# amounts  :  amount
# data  :  data
# generated  :  gener
# social  :  social
# media  :  media
# online  :  onlin
# platforms  :  platform
# .  :  .
# In  :  in
# order  :  order
# make  :  make
# sense  :  sens
# data  :  data
# ,  :  ,
# businesses  :  busi
# organizations  :  organ
# must  :  must
# invest  :  invest
# powerful  :  power
# computing  :  comput
# resources  :  resourc
# sophisticated  :  sophist
# algorithms.Another  :  algorithms.anoth
# challenge  :  challeng
# ensuring  :  ensur
# accuracy  :  accuraci
# analysis  :  analysi
# .  :  .
# Since  :  sinc
# text  :  text
# data  :  data
# often  :  often
# ambiguous  :  ambigu
# prone  :  prone
# errors  :  error
# ,  :  ,
# important  :  import
# robust  :  robust
# quality  :  qualiti
# assurance  :  assur
# process  :  process
# place  :  place
# ensure  :  ensur
# insights  :  insight
# derived  :  deriv
# text  :  text
# analytics  :  analyt
# reliable.In  :  reliable.in
# addition  :  addit
# challenges  :  challeng
# ,  :  ,
# also  :  also
# ethical  :  ethic
# considerations  :  consider
# must  :  must
# taken  :  taken
# account  :  account
# implementing  :  implement
# text  :  text
# analytics  :  analyt
# .  :  .
# For  :  for
# example  :  exampl
# ,  :  ,
# businesses  :  busi
# organizations  :  organ
# must  :  must
# mindful  :  mind
# privacy  :  privaci
# concerns  :  concern
# collecting  :  collect
# analyzing  :  analyz
# customer  :  custom
# data.Despite  :  data.despit
# challenges  :  challeng
# ,  :  ,
# text  :  text
# analytics  :  analyt
# becoming  :  becom
# increasingly  :  increasingli
# important  :  import
# tool  :  tool
# businesses  :  busi
# organizations  :  organ
# seeking  :  seek
# stay  :  stay
# competitive  :  competit
# today  :  today
# 's  :  's
# data-driven  :  data-driven
# economy  :  economi
# .  :  .
# By  :  by
# leveraging  :  leverag
# insights  :  insight
# derived  :  deriv
# text  :  text
# analytics  :  analyt
# ,  :  ,
# businesses  :  busi
# make  :  make
# informed  :  inform
# decisions  :  decis
# ,  :  ,
# improve  :  improv
# customer  :  custom
# satisfaction  :  satisfact
# ,  :  ,
# gain  :  gain
# competitive  :  competit
# edge  :  edg
# market  :  market
# .  :  .
# As  :  as
# ,  :  ,
# likely  :  like
# see  :  see
# continued  :  continu
# growth  :  growth
# use  :  use
# text  :  text
# analytics  :  analyt
# years  :  year
# come  :  come
# .  :  .

# %%
#LEMMATIZATION
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

lemmatized = []

for w in filtered_sentence:
    tp = lemmatizer.lemmatize(w,pos="a")
    lemmatized.append(tp)
    print(w,": ",tp)
# Out:
# Text :  Text
# analytics :  analytics
# , :  ,
# also :  also
# known :  known
# text :  text
# mining :  mining
# , :  ,
# process :  process
# deriving :  deriving
# meaningful :  meaningful
# insights :  insights
# patterns :  patterns
# unstructured :  unstructured
# text :  text
# data :  data
# . :  .
# With :  With
# rise :  rise
# internet :  internet
# social :  social
# media :  media
# , :  ,
# amount :  amount
# text :  text
# data :  data
# generated :  generated
# daily :  daily
# skyrocketed :  skyrocketed
# , :  ,
# making :  making
# text :  text
# analytics :  analytics
# essential :  essential
# tool :  tool
# businesses :  businesses
# organizations :  organizations
# seeking :  seeking
# extract :  extract
# insights :  insights
# data.In :  data.In
# essay :  essay
# , :  ,
# explore :  explore
# different :  different
# techniques :  techniques
# used :  used
# text :  text
# analytics :  analytics
# , :  ,
# benefits :  benefits
# text :  text
# analytics :  analytics
# , :  ,
# challenges :  challenges
# come :  come
# implementing :  implementing
# text :  text
# analytics.Text :  analytics.Text
# analytics :  analytics
# broadly :  broadly
# divided :  divided
# three :  three
# main :  main
# techniques :  techniques
# : :  :
# text :  text
# classification :  classification
# , :  ,
# sentiment :  sentiment
# analysis :  analysis
# , :  ,
# topic :  topic
# modeling.Text :  modeling.Text
# classification :  classification
# involves :  involves
# categorizing :  categorizing
# text :  text
# data :  data
# predefined :  predefined
# categories :  categories
# . :  .
# This :  This
# useful :  useful
# automating :  automating
# tasks :  tasks
# spam :  spam
# detection :  detection
# , :  ,
# content :  content
# filtering :  filtering
# , :  ,
# customer :  customer
# feedback :  feedback
# analysis :  analysis
# . :  .
# For :  For
# example :  example
# , :  ,
# company :  company
# might :  might
# use :  use
# text :  text
# classification :  classification
# automatically :  automatically
# route :  route
# customer :  customer
# complaints :  complaints
# appropriate :  appropriate
# department.Sentiment :  department.Sentiment
# analysis :  analysis
# , :  ,
# also :  also
# known :  known
# opinion :  opinion
# mining :  mining
# , :  ,
# involves :  involves
# determining :  determining
# sentiment :  sentiment
# piece :  piece
# text :  text
# data :  data
# , :  ,
# whether :  whether
# positive :  positive
# , :  ,
# negative :  negative
# , :  ,
# neutral :  neutral
# . :  .
# This :  This
# technique :  technique
# useful :  useful
# analyzing :  analyzing
# customer :  customer
# feedback :  feedback
# , :  ,
# social :  social
# media :  media
# posts :  posts
# , :  ,
# news :  news
# articles :  articles
# . :  .
# For :  For
# example :  example
# , :  ,
# company :  company
# might :  might
# use :  use
# sentiment :  sentiment
# analysis :  analysis
# track :  track
# customer :  customer
# sentiment :  sentiment
# towards :  towards
# new :  new
# product :  product
# launch.Topic :  launch.Topic
# modeling :  modeling
# involves :  involves
# identifying :  identifying
# topics :  topics
# discussed :  discussed
# piece :  piece
# text :  text
# data :  data
# . :  .
# This :  This
# technique :  technique
# useful :  useful
# identifying :  identifying
# themes :  themes
# customer :  customer
# feedback :  feedback
# , :  ,
# social :  social
# media :  media
# posts :  posts
# , :  ,
# news :  news
# articles :  articles
# . :  .
# For :  For
# example :  example
# , :  ,
# company :  company
# might :  might
# use :  use
# topic :  topic
# modeling :  modeling
# identify :  identify
# commonly :  commonly
# discussed :  discussed
# topics :  topics
# customer :  customer
# reviews :  reviews
# products.The :  products.The
# benefits :  benefits
# text :  text
# analytics :  analytics
# numerous :  numerous
# . :  .
# By :  By
# analyzing :  analyzing
# large :  large
# amounts :  amounts
# text :  text
# data :  data
# , :  ,
# businesses :  businesses
# organizations :  organizations
# gain :  gain
# valuable :  valuable
# insights :  insights
# customer :  customer
# behavior :  behavior
# , :  ,
# market :  market
# trends :  trends
# , :  ,
# brand :  brand
# reputation :  reputation
# . :  .
# For :  For
# example :  example
# , :  ,
# company :  company
# might :  might
# use :  use
# text :  text
# analytics :  analytics
# identify :  identify
# common :  common
# complaints :  complaints
# among :  among
# customers :  customers
# take :  take
# steps :  steps
# address :  address
# . :  .
# Similarly :  Similarly
# , :  ,
# marketing :  marketing
# team :  team
# might :  might
# use :  use
# text :  text
# analytics :  analytics
# identify :  identify
# popular :  popular
# keywords :  keywords
# phrases :  phrases
# social :  social
# media :  media
# posts :  posts
# inform :  inform
# advertising :  advertising
# strategy.Despite :  strategy.Despite
# many :  many
# benefits :  benefits
# , :  ,
# implementing :  implementing
# text :  text
# analytics :  analytics
# challenging :  challenging
# . :  .
# One :  One
# main :  main
# challenges :  challenges
# dealing :  dealing
# vast :  vast
# amounts :  amounts
# data :  data
# generated :  generated
# social :  social
# media :  media
# online :  online
# platforms :  platforms
# . :  .
# In :  In
# order :  order
# make :  make
# sense :  sense
# data :  data
# , :  ,
# businesses :  businesses
# organizations :  organizations
# must :  must
# invest :  invest
# powerful :  powerful
# computing :  computing
# resources :  resources
# sophisticated :  sophisticated
# algorithms.Another :  algorithms.Another
# challenge :  challenge
# ensuring :  ensuring
# accuracy :  accuracy
# analysis :  analysis
# . :  .
# Since :  Since
# text :  text
# data :  data
# often :  often
# ambiguous :  ambiguous
# prone :  prone
# errors :  errors
# , :  ,
# important :  important
# robust :  robust
# quality :  quality
# assurance :  assurance
# process :  process
# place :  place
# ensure :  ensure
# insights :  insights
# derived :  derived
# text :  text
# analytics :  analytics
# reliable.In :  reliable.In
# addition :  addition
# challenges :  challenges
# , :  ,
# also :  also
# ethical :  ethical
# considerations :  considerations
# must :  must
# taken :  taken
# account :  account
# implementing :  implementing
# text :  text
# analytics :  analytics
# . :  .
# For :  For
# example :  example
# , :  ,
# businesses :  businesses
# organizations :  organizations
# must :  must
# mindful :  mindful
# privacy :  privacy
# concerns :  concerns
# collecting :  collecting
# analyzing :  analyzing
# customer :  customer
# data.Despite :  data.Despite
# challenges :  challenges
# , :  ,
# text :  text
# analytics :  analytics
# becoming :  becoming
# increasingly :  increasingly
# important :  important
# tool :  tool
# businesses :  businesses
# organizations :  organizations
# seeking :  seeking
# stay :  stay
# competitive :  competitive
# today :  today
# 's :  's
# data-driven :  data-driven
# economy :  economy
# . :  .
# By :  By
# leveraging :  leveraging
# insights :  insights
# derived :  derived
# text :  text
# analytics :  analytics
# , :  ,
# businesses :  businesses
# make :  make
# informed :  informed
# decisions :  decisions
# , :  ,
# improve :  improve
# customer :  customer
# satisfaction :  satisfaction
# , :  ,
# gain :  gain
# competitive :  competitive
# edge :  edge
# market :  market
# . :  .
# As :  As
# , :  ,
# likely :  likely
# see :  see
# continued :  continued
# growth :  growth
# use :  use
# text :  text
# analytics :  analytics
# years :  years
# come :  come
# . :  .

# %%
#TERM FREQUENCY
total_frequency = len(lemmatized)
freq_dict = {}

for word in lemmatized:
    # If the word is already in the dictionary, increment its count
    if word in freq_dict:
        freq_dict[word] += 1
    # Otherwise, add the word to the dictionary with a count of 1
    else:
        freq_dict[word] = 1
print(freq_dict)
for key,value in freq_dict.items():
    value = float(value)/float(total_frequency)
    freq_dict[key] = value
print(freq_dict)
# Out:
# {'Text': 1, 'analytics': 14, ',': 38, 'also': 3, 'known': 2, 'text': 23, 'mining': 2, 'process': 2, 'deriving': 1, 'meaningful': 1, 'insights': 5, 'patterns': 1, 'unstructured': 1, 'data': 9, '.': 17, 'With': 1, 'rise': 1, 'internet': 1, 'social': 5, 'media': 5, 'amount': 1, 'generated': 2, 'daily': 1, 'skyrocketed': 1, 'making': 1, 'essential': 1, 'tool': 2, 'businesses': 6, 'organizations': 5, 'seeking': 2, 'extract': 1, 'data.In': 1, 'essay': 1, 'explore': 1, 'different': 1, 'techniques': 2, 'used': 1, 'benefits': 3, 'challenges': 4, 'come': 2, 'implementing': 3, 'analytics.Text': 1, 'broadly': 1, 'divided': 1, 'three': 1, 'main': 2, ':': 1, 'classification': 3, 'sentiment': 4, 'analysis': 5, 'topic': 2, 'modeling.Text': 1, 'involves': 3, 'categorizing': 1, 'predefined': 1, 'categories': 1, 'This': 3, 'useful': 3, 'automating': 1, 'tasks': 1, 'spam': 1, 'detection': 1, 'content': 1, 'filtering': 1, 'customer': 9, 'feedback': 3, 'For': 5, 'example': 5, 'company': 4, 'might': 5, 'use': 6, 'automatically': 1, 'route': 1, 'complaints': 2, 'appropriate': 1, 'department.Sentiment': 1, 'opinion': 1, 'determining': 1, 'piece': 2, 'whether': 1, 'positive': 1, 'negative': 1, 'neutral': 1, 'technique': 2, 'analyzing': 3, 'posts': 3, 'news': 2, 'articles': 2, 'track': 1, 'towards': 1, 'new': 1, 'product': 1, 'launch.Topic': 1, 'modeling': 2, 'identifying': 2, 'topics': 2, 'discussed': 2, 'themes': 1, 'identify': 3, 'commonly': 1, 'reviews': 1, 'products.The': 1, 'numerous': 1, 'By': 2, 'large': 1, 'amounts': 2, 'gain': 2, 'valuable': 1, 'behavior': 1, 'market': 2, 'trends': 1, 'brand': 1, 'reputation': 1, 'common': 1, 'among': 1, 'customers': 1, 'take': 1, 'steps': 1, 'address': 1, 'Similarly': 1, 'marketing': 1, 'team': 1, 'popular': 1, 'keywords': 1, 'phrases': 1, 'inform': 1, 'advertising': 1, 'strategy.Despite': 1, 'many': 1, 'challenging': 1, 'One': 1, 'dealing': 1, 'vast': 1, 'online': 1, 'platforms': 1, 'In': 1, 'order': 1, 'make': 2, 'sense': 1, 'must': 3, 'invest': 1, 'powerful': 1, 'computing': 1, 'resources': 1, 'sophisticated': 1, 'algorithms.Another': 1, 'challenge': 1, 'ensuring': 1, 'accuracy': 1, 'Since': 1, 'often': 1, 'ambiguous': 1, 'prone': 1, 'errors': 1, 'important': 2, 'robust': 1, 'quality': 1, 'assurance': 1, 'place': 1, 'ensure': 1, 'derived': 2, 'reliable.In': 1, 'addition': 1, 'ethical': 1, 'considerations': 1, 'taken': 1, 'account': 1, 'mindful': 1, 'privacy': 1, 'concerns': 1, 'collecting': 1, 'data.Despite': 1, 'becoming': 1, 'increasingly': 1, 'stay': 1, 'competitive': 2, 'today': 1, "'s": 1, 'data-driven': 1, 'economy': 1, 'leveraging': 1, 'informed': 1, 'decisions': 1, 'improve': 1, 'satisfaction': 1, 'edge': 1, 'As': 1, 'likely': 1, 'see': 1, 'continued': 1, 'growth': 1, 'years': 1}
# {'Text': 0.002512562814070352, 'analytics': 0.035175879396984924, ',': 0.09547738693467336, 'also': 0.007537688442211055, 'known': 0.005025125628140704, 'text': 0.05778894472361809, 'mining': 0.005025125628140704, 'process': 0.005025125628140704, 'deriving': 0.002512562814070352, 'meaningful': 0.002512562814070352, 'insights': 0.01256281407035176, 'patterns': 0.002512562814070352, 'unstructured': 0.002512562814070352, 'data': 0.022613065326633167, '.': 0.04271356783919598, 'With': 0.002512562814070352, 'rise': 0.002512562814070352, 'internet': 0.002512562814070352, 'social': 0.01256281407035176, 'media': 0.01256281407035176, 'amount': 0.002512562814070352, 'generated': 0.005025125628140704, 'daily': 0.002512562814070352, 'skyrocketed': 0.002512562814070352, 'making': 0.002512562814070352, 'essential': 0.002512562814070352, 'tool': 0.005025125628140704, 'businesses': 0.01507537688442211, 'organizations': 0.01256281407035176, 'seeking': 0.005025125628140704, 'extract': 0.002512562814070352, 'data.In': 0.002512562814070352, 'essay': 0.002512562814070352, 'explore': 0.002512562814070352, 'different': 0.002512562814070352, 'techniques': 0.005025125628140704, 'used': 0.002512562814070352, 'benefits': 0.007537688442211055, 'challenges': 0.010050251256281407, 'come': 0.005025125628140704, 'implementing': 0.007537688442211055, 'analytics.Text': 0.002512562814070352, 'broadly': 0.002512562814070352, 'divided': 0.002512562814070352, 'three': 0.002512562814070352, 'main': 0.005025125628140704, ':': 0.002512562814070352, 'classification': 0.007537688442211055, 'sentiment': 0.010050251256281407, 'analysis': 0.01256281407035176, 'topic': 0.005025125628140704, 'modeling.Text': 0.002512562814070352, 'involves': 0.007537688442211055, 'categorizing': 0.002512562814070352, 'predefined': 0.002512562814070352, 'categories': 0.002512562814070352, 'This': 0.007537688442211055, 'useful': 0.007537688442211055, 'automating': 0.002512562814070352, 'tasks': 0.002512562814070352, 'spam': 0.002512562814070352, 'detection': 0.002512562814070352, 'content': 0.002512562814070352, 'filtering': 0.002512562814070352, 'customer': 0.022613065326633167, 'feedback': 0.007537688442211055, 'For': 0.01256281407035176, 'example': 0.01256281407035176, 'company': 0.010050251256281407, 'might': 0.01256281407035176, 'use': 0.01507537688442211, 'automatically': 0.002512562814070352, 'route': 0.002512562814070352, 'complaints': 0.005025125628140704, 'appropriate': 0.002512562814070352, 'department.Sentiment': 0.002512562814070352, 'opinion': 0.002512562814070352, 'determining': 0.002512562814070352, 'piece': 0.005025125628140704, 'whether': 0.002512562814070352, 'positive': 0.002512562814070352, 'negative': 0.002512562814070352, 'neutral': 0.002512562814070352, 'technique': 0.005025125628140704, 'analyzing': 0.007537688442211055, 'posts': 0.007537688442211055, 'news': 0.005025125628140704, 'articles': 0.005025125628140704, 'track': 0.002512562814070352, 'towards': 0.002512562814070352, 'new': 0.002512562814070352, 'product': 0.002512562814070352, 'launch.Topic': 0.002512562814070352, 'modeling': 0.005025125628140704, 'identifying': 0.005025125628140704, 'topics': 0.005025125628140704, 'discussed': 0.005025125628140704, 'themes': 0.002512562814070352, 'identify': 0.007537688442211055, 'commonly': 0.002512562814070352, 'reviews': 0.002512562814070352, 'products.The': 0.002512562814070352, 'numerous': 0.002512562814070352, 'By': 0.005025125628140704, 'large': 0.002512562814070352, 'amounts': 0.005025125628140704, 'gain': 0.005025125628140704, 'valuable': 0.002512562814070352, 'behavior': 0.002512562814070352, 'market': 0.005025125628140704, 'trends': 0.002512562814070352, 'brand': 0.002512562814070352, 'reputation': 0.002512562814070352, 'common': 0.002512562814070352, 'among': 0.002512562814070352, 'customers': 0.002512562814070352, 'take': 0.002512562814070352, 'steps': 0.002512562814070352, 'address': 0.002512562814070352, 'Similarly': 0.002512562814070352, 'marketing': 0.0025 ...

# %%
#IDF INVERSE DOCUMENT FREQUENCY
# Split main para into 3 separate documents
import math

length = len(lemmatized)

# Calculate the approximate length of each substring
substring_length = length // 3

# Split the array into three substrings
substring1 = lemmatized[:substring_length]
substring2 = lemmatized[substring_length:2*substring_length]
substring3 = lemmatized[2*substring_length:]

idf_dict={}
N = 3

for word in lemmatized:
    count=0
    if word in substring1:
        count+=1
    if word in substring2:
        count+=1
    if word in substring3:
        count+=1
    tp = float(N/count)
    ans = math.log10(tp)
    if word in idf_dict:
        pass
    else:
        idf_dict[word]=ans

# %%
idf_dict
# Out:
# {'Text': 0.47712125471966244,
#  'analytics': 0.0,
#  ',': 0.0,
#  'also': 0.17609125905568124,
#  'known': 0.47712125471966244,
#  'text': 0.0,
#  'mining': 0.47712125471966244,
#  'process': 0.17609125905568124,
#  'deriving': 0.47712125471966244,
#  'meaningful': 0.47712125471966244,
#  'insights': 0.0,
#  'patterns': 0.47712125471966244,
#  'unstructured': 0.47712125471966244,
#  'data': 0.0,
#  '.': 0.0,
#  'With': 0.47712125471966244,
#  'rise': 0.47712125471966244,
#  'internet': 0.47712125471966244,
#  'social': 0.0,
#  'media': 0.0,
#  'amount': 0.47712125471966244,
#  'generated': 0.17609125905568124,
#  'daily': 0.47712125471966244,
#  'skyrocketed': 0.47712125471966244,
#  'making': 0.47712125471966244,
#  'essential': 0.47712125471966244,
#  'tool': 0.17609125905568124,
#  'businesses': 0.0,
#  'organizations': 0.0,
#  'seeking': 0.17609125905568124,
#  'extract': 0.47712125471966244,
#  'data.In': 0.47712125471966244,
#  'essay': 0.47712125471966244,
#  'explore': 0.47712125471966244,
#  'different': 0.47712125471966244,
#  'techniques': 0.47712125471966244,
#  'used': 0.47712125471966244,
#  'benefits': 0.17609125905568124,
#  'challenges': 0.17609125905568124,
#  'come': 0.17609125905568124,
#  'implementing': 0.0,
#  'analytics.Text': 0.47712125471966244,
#  'broadly': 0.47712125471966244,
#  'divided': 0.47712125471966244,
#  'three': 0.47712125471966244,
#  'main': 0.17609125905568124,
#  ':': 0.47712125471966244,
#  'classification': 0.47712125471966244,
#  'sentiment': 0.17609125905568124,
#  'analysis': 0.0,
#  'topic': 0.17609125905568124,
#  'modeling.Text': 0.47712125471966244,
#  'involves': 0.17609125905568124,
#  'categorizing': 0.47712125471966244,
#  'predefined': 0.47712125471966244,
#  'categories': 0.47712125471966244,
#  'This': 0.17609125905568124,
#  'useful': 0.17609125905568124,
#  'automating': 0.47712125471966244,
#  'tasks': 0.47712125471966244,
#  'spam': 0.47712125471966244,
#  'detection': 0.47712125471966244,
#  'content': 0.47712125471966244,
#  'filtering': 0.47712125471966244,
#  'customer': 0.0,
#  'feedback': 0.17609125905568124,
#  'For': 0.0,
#  'example': 0.0,
#  'company': 0.17609125905568124,
#  'might': 0.17609125905568124,
#  'use': 0.0,
#  'automatically': 0.47712125471966244,
#  'route': 0.47712125471966244,
#  'complaints': 0.17609125905568124,
#  'appropriate': 0.47712125471966244,
#  'department.Sentiment': 0.47712125471966244,
#  'opinion': 0.47712125471966244,
#  'determining': 0.47712125471966244,
#  'piece': 0.17609125905568124,
#  'whether': 0.47712125471966244,
#  'positive': 0.47712125471966244,
#  'negative': 0.47712125471966244,
#  'neutral': 0.47712125471966244,
#  'technique': 0.47712125471966244,
#  'analyzing': 0.17609125905568124,
#  'posts': 0.47712125471966244,
#  'news': 0.47712125471966244,
#  'articles': 0.47712125471966244,
#  'track': 0.47712125471966244,
#  'towards': 0.47712125471966244,
#  'new': 0.47712125471966244,
#  'product': 0.47712125471966244,
#  'launch.Topic': 0.47712125471966244,
#  'modeling': 0.47712125471966244,
#  'identifying': 0.47712125471966244,
#  'topics': 0.47712125471966244,
#  'discussed': 0.47712125471966244,
#  'themes': 0.47712125471966244,
#  'identify': 0.47712125471966244,
#  'commonly': 0.47712125471966244,
#  'reviews': 0.47712125471966244,
#  'products.The': 0.47712125471966244,
#  'numerous': 0.47712125471966244,
#  'By': 0.17609125905568124,
#  'large': 0.47712125471966244,
#  'amounts': 0.17609125905568124,
#  'gain': 0.17609125905568124,
#  'valuable': 0.47712125471966244,
#  'behavior': 0.47712125471966244,
#  'market': 0.17609125905568124,
#  'trends': 0.47712125471966244,
#  'brand': 0.47712125471966244,
#  'reputation': 0.47712125471966244,
#  'common': 0.47712125471966244,
#  'among': 0.47712125471966244,
#  'customers': 0.47712125471966244,
#  'take': 0.47712125471966244,
#  'steps': 0.47712125471966244,
#  'address': 0.47712125471966244,
#  'Similarly': 0.47712125471966244,
#  'marketing': 0.47712125471966244,
#  'team': 0.47712125471966244,
#  'popular': 0.47712125471966244,
#  'keywords': 0.47712125471966244,
#  'phrases': 0.47712125471966244,
#  'inform': 0.47712125471966244,
#  'advertising': 0.47712125471966244,
#  'strategy.Despite': 0.47712125471966244,
#  'many': 0.47712125471966244,
#  'challenging': 0.47712125471966244,
#  'One': 0.47712125471966244,
#  'dealing': 0.47712125471966244,
#  'vast': 0.47712125471966244,
#  'online': 0.47712125471966244,
#  'platforms': 0.47712125471966244,
#  'In': 0.47712125471966244,
#  'order': 0.47712125471966244,
#  'make': 0.47712125471966244,
#  'sense': 0.47712125471966244,
#  'must': 0.47712125471966244,
#  'invest': 0.47712125471966244,
#  'powerful': 0.47712125471966244,
#  'computing': 0.47712125471966244,
#  'resources': 0.47712125471966244,
#  'sophisticated': 0.47712125471966244,
#  'algorithms.Another': 0.47712125471966244,
#  'challenge': 0.47712125471966244,
#  'ensuring': 0.47712125471966244,
#  'accuracy': 0.47712125471966244,
#  'Since': 0.47712125471966244,
#  'often': 0.47712125471966244,
#  'ambiguous': 0.47712125471966244,
#  'prone': 0.47712125471966244,
#  'errors': 0.47712125471966244,
#  'important': 0.47712125471966244,
#  'robust': 0.47712125471966244,
#  'quality': 0.47712125471966244,
#  'assurance': 0.47712125471966244,
#  'place': 0.47712125471966244,
#  'ensure': 0.47712125471966244,
#  'derived': 0.47712125471966244,
#  'reliable.In': 0.47712125471966244,
#  'addition': 0.47712125471966244,
#  'ethical': 0.47712125471966244,
#  'considerations': 0.47712125471966244,
#  'taken': 0.47712125471966244,
#  'account': 0.47712125471966244,
#  'mindful': 0.47712125471966244,
#  'privacy': 0.47712125471966244,
#  'concerns': 0.47712125471966244,
#  'collecting': 0.47712125471966244,
#  'data.Despite': 0.47712125471966244,
#  'becoming': 0.47712125471966244,
#  'increasingly': 0.47712125471966244,
#  'stay': 0.47712125471966244,
#  'competitive': 0.47712125471966244,
#  'today': 0.47712125471966244,
#  "'s": 0.47712125471966244,
#  'data-driven': 0.47712125471966244,
#  'economy': 0.47712125471966244,
#  'leveraging': 0.47712125471966244,
#  'informed': 0.47712125471966244,
#  'decisions': 0.47712125471966244,
#  'improve': 0.47712125471966244,
#  'satisfaction': 0.47712125471966244,
#  'edge': 0.47712125471966244,
#  'As': 0.47712125471966244,
#  'likely': 0.47712125471966244,
#  'see': 0.47712125471966244,
#  'continued': 0.47712125471966244,
#  'growth': 0.47712125471966244,
#  'years': 0.47712125471966244}
